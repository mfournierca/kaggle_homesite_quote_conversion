# %%
## Load Data

# %%
import matplotlib
# %matplotlib inline

import pandas as pd
import numpy as np

import os

def get_data_file(name):
    return os.path.join(os.getcwd(), "source_data", name)

# %%
df = pd.read_csv(get_data_file("train.csv"))
df.head()
# Out:
#    QuoteNumber Original_Quote_Date  QuoteConversion_Flag Field6  Field7  \
# 0            1          2013-08-16                     0      B      23
# 1            2          2014-04-22                     0      F       7
# 2            4          2014-08-25                     0      F       7
# 3            6          2013-04-15                     0      J      10
# 4            8          2014-01-25                     0      E      23
#
#    Field8  Field9 Field10  Field11 Field12        ...          \
# 0  0.9403  0.0006     965   1.0200       N        ...
# 1  1.0006  0.0040     548   1.2433       N        ...
# 2  1.0006  0.0040     548   1.2433       N        ...
# 3  0.9769  0.0004   1,165   1.2665       N        ...
# 4  0.9472  0.0006   1,487   1.3045       N        ...
#
#    GeographicField59A  GeographicField59B  GeographicField60A  \
# 0                   9                   9                  -1
# 1                  10                  10                  -1
# 2                  15                  18                  -1
# 3                   6                   5                  -1
# 4                  18                  22                  -1
#
#    GeographicField60B  GeographicField61A  GeographicField61B  \
# 0                   8                  -1                  18
# 1                  11                  -1                  17
# 2                  21                  -1                  11
# 3                  10                  -1                   9
# 4                  10                  -1                  11
#
#    GeographicField62A  GeographicField62B  GeographicField63  \
# 0                  -1                  10                  N
# 1                  -1                  20                  N
# 2                  -1                   8                  N
# 3                  -1                  21                  N
# 4                  -1                  12                  N
#
#    GeographicField64
# 0                 CA
# 1                 NJ
# 2                 NJ
# 3                 TX
# 4                 IL
#
# [5 rows x 299 columns]

# %%
len(list(df.columns))
# Out:
# 299

# %%
df.select_dtypes(exclude=["number"]).head()
# Out:
#   Original_Quote_Date Field6 Field10 Field12 CoverageField8 CoverageField9  \
# 0          2013-08-16      B     965       N              T              D
# 1          2014-04-22      F     548       N              T              E
# 2          2014-08-25      F     548       N              T              J
# 3          2013-04-15      J   1,165       N              Y              F
# 4          2014-01-25      E   1,487       N              T              F
#
#   SalesField7 PersonalField16 PersonalField17 PersonalField18  \
# 0           V              ZA              ZE              XR
# 1           P              XB              YJ              YE
# 2           K              ZH              XS              YP
# 3           V              XO              XE              YI
# 4           R              ZA              ZE              XR
#
#          ...        PropertyField5 PropertyField7 PropertyField14  \
# 0        ...                     Y              O               C
# 1        ...                     Y              N               B
# 2        ...                     Y              R               C
# 3        ...                     Y              R               C
# 4        ...                     Y              D               A
#
#   PropertyField28 PropertyField30 PropertyField31 PropertyField33  \
# 0               B               N               N               G
# 1               B               N               O               H
# 2               B               N               K               H
# 3               B               N               O               G
# 4               B               N               O               H
#
#   PropertyField37 GeographicField63 GeographicField64
# 0               N                 N                CA
# 1               N                 N                NJ
# 2               N                 N                NJ
# 3               Y                 N                TX
# 4               N                 N                IL
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#          QuoteNumber  QuoteConversion_Flag         Field7         Field8  \
# count  260753.000000         260753.000000  260753.000000  260753.000000
# mean   217201.246011              0.187511      18.293339       0.938346
# std    125478.522633              0.390322       7.382803       0.037086
# min         1.000000              0.000000       1.000000       0.874600
# 25%    108517.000000              0.000000      11.000000       0.915300
# 50%    217012.000000              0.000000      23.000000       0.940300
# 75%    325905.000000              0.000000      24.000000       0.968500
# max    434588.000000              1.000000      28.000000       1.010100
#
#               Field9        Field11  CoverageField1A  CoverageField1B  \
# count  260753.000000  260753.000000    260753.000000    260753.000000
# mean        0.001451       1.162718         9.012533        13.000403
# std         0.001486       0.116833         5.576509         7.219264
# min         0.000400       1.000000        -1.000000        -1.000000
# 25%         0.000600       1.020000         5.000000         7.000000
# 50%         0.000600       1.188600         8.000000        13.000000
# 75%         0.003800       1.266500        12.000000        19.000000
# max         0.004000       1.304500        25.000000        25.000000
#
#        CoverageField2A  CoverageField2B         ...          \
# count    260753.000000    260753.000000         ...
# mean          9.054005        13.015240         ...
# std           5.560521         7.211717         ...
# min           1.000000         1.000000         ...
# 25%           5.000000         7.000000         ...
# 50%           8.000000        13.000000         ...
# 75%          12.000000        19.000000         ...
# max          25.000000        25.000000         ...
#
#        GeographicField58A  GeographicField58B  GeographicField59A  \
# count       260753.000000       260753.000000       260753.000000
# mean            11.567756           12.985695           11.694903
# std              5.448425            7.216091            5.626092
# min             -1.000000           -1.000000           -1.000000
# 25%              8.000000            7.000000            7.000000
# 50%             11.000000           13.000000           11.000000
# 75%             15.000000           19.000000           15.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField59B  GeographicField60A  GeographicField60B  \
# count       260753.000000       260753.000000       260753.000000
# mean            13.049882           -0.350481           12.994362
# std              7.213636            4.057792            7.219943
# min             -1.000000           -1.000000           -1.000000
# 25%              7.000000           -1.000000            7.000000
# 50%             13.000000           -1.000000           13.000000
# 75%             19.000000           -1.000000           19.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField61A  GeographicField61B  GeographicField62A  \
# count       260753.000000       260753.000000       260753.000000
# mean            -0.343601           13.042734           -0.341009
# std              4.078673            7.145248            4.086511
# min             -1.000000           -1.000000           -1.000000
# 25%             -1.000000            7.000000           -1.000000
# 50%             -1.000000           13.000000           -1.000000
# 75%             -1.000000           19.000000           -1.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField62B
# count       260753.000000
# mean            14.122948
# std              5.829091
# min             -1.000000
# 25%              8.000000
# 50%             13.000000
# 75%             19.000000
# max             25.000000
#
# [8 rows x 271 columns]

# %% [markdown]
# ## Clean Data

# %%
def clean_data(df):
    df["Original_Quote_Date"] = df["Original_Quote_Date"].apply(pd.to_datetime)
    df["Original_Quote_Month"] = df["Original_Quote_Date"].apply(lambda d: d.month)
    df = df.dropna(how="any", axis=1)
    return df

# %%
df = clean_data(df)

# %%
df.head()["Original_Quote_Date"]
# Out:
# 0   2013-08-16
# 1   2014-04-22
# 2   2014-08-25
# 3   2013-04-15
# 4   2014-01-25
# Name: Original_Quote_Date, dtype: datetime64[ns]

# %%
df["Original_Quote_Date"].min()
# Out:
# Timestamp('2013-01-01 00:00:00')

# %%
df["Original_Quote_Date"].max()
# Out:
# Timestamp('2015-05-18 00:00:00')

# %%
df.describe()
# Out:
#          QuoteNumber  QuoteConversion_Flag         Field7         Field8  \
# count  260753.000000         260753.000000  260753.000000  260753.000000
# mean   217201.246011              0.187511      18.293339       0.938346
# std    125478.522633              0.390322       7.382803       0.037086
# min         1.000000              0.000000       1.000000       0.874600
# 25%    108517.000000              0.000000      11.000000       0.915300
# 50%    217012.000000              0.000000      23.000000       0.940300
# 75%    325905.000000              0.000000      24.000000       0.968500
# max    434588.000000              1.000000      28.000000       1.010100
#
#               Field9        Field11  CoverageField1A  CoverageField1B  \
# count  260753.000000  260753.000000    260753.000000    260753.000000
# mean        0.001451       1.162718         9.012533        13.000403
# std         0.001486       0.116833         5.576509         7.219264
# min         0.000400       1.000000        -1.000000        -1.000000
# 25%         0.000600       1.020000         5.000000         7.000000
# 50%         0.000600       1.188600         8.000000        13.000000
# 75%         0.003800       1.266500        12.000000        19.000000
# max         0.004000       1.304500        25.000000        25.000000
#
#        CoverageField2A  CoverageField2B          ...           \
# count    260753.000000    260753.000000          ...
# mean          9.054005        13.015240          ...
# std           5.560521         7.211717          ...
# min           1.000000         1.000000          ...
# 25%           5.000000         7.000000          ...
# 50%           8.000000        13.000000          ...
# 75%          12.000000        19.000000          ...
# max          25.000000        25.000000          ...
#
#        GeographicField58B  GeographicField59A  GeographicField59B  \
# count       260753.000000       260753.000000       260753.000000
# mean            12.985695           11.694903           13.049882
# std              7.216091            5.626092            7.213636
# min             -1.000000           -1.000000           -1.000000
# 25%              7.000000            7.000000            7.000000
# 50%             13.000000           11.000000           13.000000
# 75%             19.000000           15.000000           19.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField60A  GeographicField60B  GeographicField61A  \
# count       260753.000000       260753.000000       260753.000000
# mean            -0.350481           12.994362           -0.343601
# std              4.057792            7.219943            4.078673
# min             -1.000000           -1.000000           -1.000000
# 25%             -1.000000            7.000000           -1.000000
# 50%             -1.000000           13.000000           -1.000000
# 75%             -1.000000           19.000000           -1.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField61B  GeographicField62A  GeographicField62B  \
# count       260753.000000       260753.000000       260753.000000
# mean            13.042734           -0.341009           14.122948
# std              7.145248            4.086511            5.829091
# min             -1.000000           -1.000000           -1.000000
# 25%              7.000000           -1.000000            8.000000
# 50%             13.000000           -1.000000           13.000000
# 75%             19.000000           -1.000000           19.000000
# max             25.000000           25.000000           25.000000
#
#        Original_Quote_Month
# count         260753.000000
# mean               5.675532
# std                3.305120
# min                1.000000
# 25%                3.000000
# 50%                5.000000
# 75%                8.000000
# max               12.000000
#
# [8 rows x 270 columns]

# %% [markdown]
# ## Visualize

# %%
import seaborn as sns
sns.distplot(df["Original_Quote_Month"], kde=False)

# %%
pd.get_dummies(df["Field6"]).sum()
# Out:
# A       35
# B    94694
# C     5660
# D      240
# E    26063
# F    69053
# J    51782
# K    13226
# dtype: float64

# %%
pd.get_dummies(df["GeographicField64"]).sum()
# Out:
# CA    94725
# IL    31724
# NJ    69293
# TX    65011
# dtype: float64

# %%
def get_categorical(df, col="GeographicField64"):
    df_region = pd.merge(
        df, 
        pd.get_dummies(df[col]), 
        how="inner", 
        left_index=True, 
        right_index=True
    )
    return df_region

# %%
df_region = get_categorical(df, col="GeographicField64")
df_region = get_categorical(df, col="GeographicField63")
df_region = get_categorical(df, col="Field6")
df_region = get_categorical(df, col="Field12")
df_region = get_categorical(df, col="GeographicField64")
df_region = get_categorical(df, col="GeographicField64")
df_region = get_categorical(df, col="GeographicField64")
df_region.head()
# Out:
#    QuoteNumber Original_Quote_Date  QuoteConversion_Flag Field6  Field7  \
# 0            1          2013-08-16                     0      B      23
# 1            2          2014-04-22                     0      F       7
# 2            4          2014-08-25                     0      F       7
# 3            6          2013-04-15                     0      J      10
# 4            8          2014-01-25                     0      E      23
#
#    Field8  Field9 Field10  Field11 Field12 ...  GeographicField61B  \
# 0  0.9403  0.0006     965   1.0200       N ...                  18
# 1  1.0006  0.0040     548   1.2433       N ...                  17
# 2  1.0006  0.0040     548   1.2433       N ...                  11
# 3  0.9769  0.0004   1,165   1.2665       N ...                   9
# 4  0.9472  0.0006   1,487   1.3045       N ...                  11
#
#    GeographicField62A  GeographicField62B  GeographicField63  \
# 0                  -1                  10                  N
# 1                  -1                  20                  N
# 2                  -1                   8                  N
# 3                  -1                  21                  N
# 4                  -1                  12                  N
#
#    GeographicField64  Original_Quote_Month  CA  IL  NJ  TX
# 0                 CA                     8   1   0   0   0
# 1                 NJ                     4   0   0   1   0
# 2                 NJ                     8   0   0   1   0
# 3                 TX                     4   0   0   0   1
# 4                 IL                     1   0   1   0   0
#
# [5 rows x 295 columns]

# %% [markdown]
# use above in logistic regression
# for logistic regression, higher dimension is better
# curse of dimensionality works in our favour with logistic regression, makes cut easier

# %%
df_region[["QuoteConversion_Flag", "CA"]][df_region["CA"] == 1].sum()
# Out:
# QuoteConversion_Flag    19836
# CA                      94725
# dtype: float64

# %%
df_region[["QuoteConversion_Flag", "IL"]][df_region["IL"] == 1].sum()
# Out:
# QuoteConversion_Flag     4121
# IL                      31724
# dtype: float64

# %%
df_region[["QuoteConversion_Flag", "NJ"]][df_region["NJ"] == 1].sum()
# Out:
# QuoteConversion_Flag    20710
# NJ                      69293
# dtype: float64

# %%
df_region[["QuoteConversion_Flag", "TX"]][df_region["TX"] == 1].sum()
# Out:
# QuoteConversion_Flag     4227
# TX                      65011
# dtype: float64

# %% [markdown]
# ## Pipeline

# %%
from sklearn.preprocessing import normalize
def select_predictors_and_normalize(df):
    df_predictors = df[[c for c in df.columns if c not in ["QuoteConversion_Flag"]]]
    df_predictors = df_predictors.select_dtypes(["number"])
    # df_normalized = normalize(df_predictors)
    # df_normalized = pd.DataFrame(df_normalized)
    return df_predictors

# %%
df_normalized = select_predictors_and_normalize(df_region)
df_normalized.head()
# Out:
#    QuoteNumber  Field7  Field8  Field9  Field11  CoverageField1A  \
# 0            1      23  0.9403  0.0006   1.0200               17
# 1            2       7  1.0006  0.0040   1.2433                6
# 2            4       7  1.0006  0.0040   1.2433                7
# 3            6      10  0.9769  0.0004   1.2665                3
# 4            8      23  0.9472  0.0006   1.3045                8
#
#    CoverageField1B  CoverageField2A  CoverageField2B  CoverageField3A ...  \
# 0               23               17               23               15 ...
# 1                8                6                8                5 ...
# 2               12                7               12                6 ...
# 3                2                3                2                2 ...
# 4               13                8               13                7 ...
#
#    GeographicField60B  GeographicField61A  GeographicField61B  \
# 0                   8                  -1                  18
# 1                  11                  -1                  17
# 2                  21                  -1                  11
# 3                  10                  -1                   9
# 4                  10                  -1                  11
#
#    GeographicField62A  GeographicField62B  Original_Quote_Month  CA  IL  NJ  \
# 0                  -1                  10                     8   1   0   0
# 1                  -1                  20                     4   0   0   1
# 2                  -1                   8                     8   0   0   1
# 3                  -1                  21                     4   0   0   0
# 4                  -1                  12                     1   0   1   0
#
#    TX
# 0   0
# 1   0
# 2   0
# 3   1
# 4   0
#
# [5 rows x 273 columns]

# %% [markdown]
# ### Feature Selection

# %%
from sklearn.feature_selection import VarianceThreshold
vt = VarianceThreshold()
vt.fit(df_normalized)
# Out:
# VarianceThreshold(threshold=0.0)

# %%
# df_varthreshold = vt.transform(df_normalized)
df_varthreshold = df_normalized

# %%
len(df_varthreshold)
# Out:
# 260753

# %%
len(df_varthreshold.columns)
# Out:
# 273

# %%
df_varthreshold = pd.DataFrame(df_varthreshold)

# %%
df_varthreshold.describe()
# Out:
#          QuoteNumber         Field7         Field8         Field9  \
# count  260753.000000  260753.000000  260753.000000  260753.000000
# mean   217201.246011      18.293339       0.938346       0.001451
# std    125478.522633       7.382803       0.037086       0.001486
# min         1.000000       1.000000       0.874600       0.000400
# 25%    108517.000000      11.000000       0.915300       0.000600
# 50%    217012.000000      23.000000       0.940300       0.000600
# 75%    325905.000000      24.000000       0.968500       0.003800
# max    434588.000000      28.000000       1.010100       0.004000
#
#              Field11  CoverageField1A  CoverageField1B  CoverageField2A  \
# count  260753.000000    260753.000000    260753.000000    260753.000000
# mean        1.162718         9.012533        13.000403         9.054005
# std         0.116833         5.576509         7.219264         5.560521
# min         1.000000        -1.000000        -1.000000         1.000000
# 25%         1.020000         5.000000         7.000000         5.000000
# 50%         1.188600         8.000000        13.000000         8.000000
# 75%         1.266500        12.000000        19.000000        12.000000
# max         1.304500        25.000000        25.000000        25.000000
#
#        CoverageField2B  CoverageField3A      ...       GeographicField60B  \
# count    260753.000000    260753.000000      ...            260753.000000
# mean         13.015240         9.053150      ...                12.994362
# std           7.211717         5.579687      ...                 7.219943
# min           1.000000         1.000000      ...                -1.000000
# 25%           7.000000         5.000000      ...                 7.000000
# 50%          13.000000         8.000000      ...                13.000000
# 75%          19.000000        12.000000      ...                19.000000
# max          25.000000        25.000000      ...                25.000000
#
#        GeographicField61A  GeographicField61B  GeographicField62A  \
# count       260753.000000       260753.000000       260753.000000
# mean            -0.343601           13.042734           -0.341009
# std              4.078673            7.145248            4.086511
# min             -1.000000           -1.000000           -1.000000
# 25%             -1.000000            7.000000           -1.000000
# 50%             -1.000000           13.000000           -1.000000
# 75%             -1.000000           19.000000           -1.000000
# max             25.000000           25.000000           25.000000
#
#        GeographicField62B  Original_Quote_Month             CA             IL  \
# count       260753.000000         260753.000000  260753.000000  260753.000000
# mean            14.122948              5.675532       0.363275       0.121663
# std              5.829091              3.305120       0.480944       0.326897
# min             -1.000000              1.000000       0.000000       0.000000
# 25%              8.000000              3.000000       0.000000       0.000000
# 50%             13.000000              5.000000       0.000000       0.000000
# 75%             19.000000              8.000000       1.000000       0.000000
# max             25.000000             12.000000       1.000000       1.000000
#
#                   NJ            TX
# count  260753.000000  260753.00000
# mean        0.265742       0.24932
# std         0.441728       0.43262
# min         0.000000       0.00000
# 25%         0.000000       0.00000
# 50%         0.000000       0.00000
# 75%         1.000000       0.00000
# max         1.000000       1.00000
#
# [8 rows x 273 columns]

# %%
df_varthreshold.head()
# Out:
#    QuoteNumber  Field7  Field8  Field9  Field11  CoverageField1A  \
# 0            1      23  0.9403  0.0006   1.0200               17
# 1            2       7  1.0006  0.0040   1.2433                6
# 2            4       7  1.0006  0.0040   1.2433                7
# 3            6      10  0.9769  0.0004   1.2665                3
# 4            8      23  0.9472  0.0006   1.3045                8
#
#    CoverageField1B  CoverageField2A  CoverageField2B  CoverageField3A ...  \
# 0               23               17               23               15 ...
# 1                8                6                8                5 ...
# 2               12                7               12                6 ...
# 3                2                3                2                2 ...
# 4               13                8               13                7 ...
#
#    GeographicField60B  GeographicField61A  GeographicField61B  \
# 0                   8                  -1                  18
# 1                  11                  -1                  17
# 2                  21                  -1                  11
# 3                  10                  -1                   9
# 4                  10                  -1                  11
#
#    GeographicField62A  GeographicField62B  Original_Quote_Month  CA  IL  NJ  \
# 0                  -1                  10                     8   1   0   0
# 1                  -1                  20                     4   0   0   1
# 2                  -1                   8                     8   0   0   1
# 3                  -1                  21                     4   0   0   0
# 4                  -1                  12                     1   0   1   0
#
#    TX
# 0   0
# 1   0
# 2   0
# 3   1
# 4   0
#
# [5 rows x 273 columns]

# %% [markdown]
# ### Model Building

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df_varthreshold, 
    df["QuoteConversion_Flag"], 
    test_size=0.33, 
    random_state=42
)

# %% [markdown]
# #### Logistic Regression

# %% [markdown]
# ##### build

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(
    X_train,
    y_train
)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ##### evaluate

# %%
lr.score(X_test, y_test)
# Out:
# 0.81188625085706978
